# %%
import pandas as pd

# %%
print("Welcome to the jupyter notebook")
# Out:
# Welcome to the jupyter notebook

# %%
from pandas_profiling import profileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7544/203115269.py in <module>
# ----> 1 from pandas_profiling import profileReport
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\__init__.py in <module>
#       4 """
#       5
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\controller\pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       5
#       6
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\profile_report.py in <module>
#      11 from visions import VisionsTypeset
#      12
# ---> 13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
#      15 from pandas_profiling.model.describe import describe as describe_df
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\config.py in <module>
#       3 from typing import Any, Dict, List, Optional
#       4
# ----> 5 from pydantic import BaseModel, BaseSettings, Field
#       6
#       7
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\__init__.py in <module>
#       1 # flake8: noqa
# ----> 2 from . import dataclasses
#       3 from .annotated_types import create_model_from_namedtuple, create_model_from_typeddict
#       4 from .class_validators import root_validator, validator
#       5 from .decorator import validate_arguments
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\dataclasses.py in <module>
#       1 from typing import TYPE_CHECKING, Any, Callable, Dict, Optional, Type, TypeVar, Union, overload
#       2
# ----> 3 from .class_validators import gather_all_validators
#       4 from .error_wrappers import ValidationError
#       5 from .errors import DataclassTypeError
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\class_validators.py in <module>
#       6 from typing import TYPE_CHECKING, Any, Callable, Dict, Iterable, List, Optional, Set, Tuple, Type, Union, overload
#       7
# ----> 8 from .errors import ConfigError
#       9 from .typing import AnyCallable
#      10 from .utils import ROOT_KEY, in_ipython
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\errors.py in <module>
#       3 from typing import TYPE_CHECKING, Any, Callable, Set, Tuple, Type, Union
#       4
# ----> 5 from .typing import display_as_type
#       6
#       7 if TYPE_CHECKING:
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\typing.py in <module>
#      21 )
#      22
# ---> 23 from typing_extensions import Annotated, Literal
#      24
#      25 try:
#
# ModuleNotFoundError: No module named 'typing_extensions'

# %%
from pandas_profiling import profileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7544/203115269.py in <module>
# ----> 1 from pandas_profiling import profileReport
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\__init__.py in <module>
#       4 """
#       5
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\controller\pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       5
#       6
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\profile_report.py in <module>
#      11 from visions import VisionsTypeset
#      12
# ---> 13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
#      15 from pandas_profiling.model.describe import describe as describe_df
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\config.py in <module>
#       3 from typing import Any, Dict, List, Optional
#       4
# ----> 5 from pydantic import BaseModel, BaseSettings, Field
#       6
#       7
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\__init__.py in <module>
#       1 # flake8: noqa
# ----> 2 from . import dataclasses
#       3 from .annotated_types import create_model_from_namedtuple, create_model_from_typeddict
#       4 from .class_validators import root_validator, validator
#       5 from .decorator import validate_arguments
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\dataclasses.py in <module>
#       1 from typing import TYPE_CHECKING, Any, Callable, Dict, Optional, Type, TypeVar, Union, overload
#       2
# ----> 3 from .class_validators import gather_all_validators
#       4 from .error_wrappers import ValidationError
#       5 from .errors import DataclassTypeError
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\class_validators.py in <module>
#       6 from typing import TYPE_CHECKING, Any, Callable, Dict, Iterable, List, Optional, Set, Tuple, Type, Union, overload
#       7
# ----> 8 from .errors import ConfigError
#       9 from .typing import AnyCallable
#      10 from .utils import ROOT_KEY, in_ipython
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\errors.py in <module>
#       3 from typing import TYPE_CHECKING, Any, Callable, Set, Tuple, Type, Union
#       4
# ----> 5 from .typing import display_as_type
#       6
#       7 if TYPE_CHECKING:
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\typing.py in <module>
#      21 )
#      22
# ---> 23 from typing_extensions import Annotated, Literal
#      24
#      25 try:
#
# ModuleNotFoundError: No module named 'typing_extensions'

# %%
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7544/2274191625.py in <module>
# ----> 1 from pandas_profiling import ProfileReport
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\__init__.py in <module>
#       4 """
#       5
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\controller\pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       5
#       6
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\profile_report.py in <module>
#      11 from visions import VisionsTypeset
#      12
# ---> 13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
#      15 from pandas_profiling.model.describe import describe as describe_df
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\config.py in <module>
#       3 from typing import Any, Dict, List, Optional
#       4
# ----> 5 from pydantic import BaseModel, BaseSettings, Field
#       6
#       7
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\__init__.py in <module>
#       1 # flake8: noqa
# ----> 2 from . import dataclasses
#       3 from .annotated_types import create_model_from_namedtuple, create_model_from_typeddict
#       4 from .class_validators import root_validator, validator
#       5 from .decorator import validate_arguments
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\dataclasses.py in <module>
#       1 from typing import TYPE_CHECKING, Any, Callable, Dict, Optional, Type, TypeVar, Union, overload
#       2
# ----> 3 from .class_validators import gather_all_validators
#       4 from .error_wrappers import ValidationError
#       5 from .errors import DataclassTypeError
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\class_validators.py in <module>
#       6 from typing import TYPE_CHECKING, Any, Callable, Dict, Iterable, List, Optional, Set, Tuple, Type, Union, overload
#       7
# ----> 8 from .errors import ConfigError
#       9 from .typing import AnyCallable
#      10 from .utils import ROOT_KEY, in_ipython
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\errors.py in <module>
#       3 from typing import TYPE_CHECKING, Any, Callable, Set, Tuple, Type, Union
#       4
# ----> 5 from .typing import display_as_type
#       6
#       7 if TYPE_CHECKING:
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\typing.py in <module>
#      21 )
#      22
# ---> 23 from typing_extensions import Annotated, Literal
#      24
#      25 try:
#
# ModuleNotFoundError: No module named 'typing_extensions'

# %%
from pandas_profiling.profile_report import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7544/1228782139.py in <module>
# ----> 1 from pandas_profiling.profile_report import ProfileReport
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\__init__.py in <module>
#       4 """
#       5
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\controller\pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       5
#       6
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\profile_report.py in <module>
#      11 from visions import VisionsTypeset
#      12
# ---> 13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
#      15 from pandas_profiling.model.describe import describe as describe_df
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\config.py in <module>
#       3 from typing import Any, Dict, List, Optional
#       4
# ----> 5 from pydantic import BaseModel, BaseSettings, Field
#       6
#       7
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\__init__.py in <module>
#       1 # flake8: noqa
# ----> 2 from . import dataclasses
#       3 from .annotated_types import create_model_from_namedtuple, create_model_from_typeddict
#       4 from .class_validators import root_validator, validator
#       5 from .decorator import validate_arguments
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\dataclasses.py in <module>
#       1 from typing import TYPE_CHECKING, Any, Callable, Dict, Optional, Type, TypeVar, Union, overload
#       2
# ----> 3 from .class_validators import gather_all_validators
#       4 from .error_wrappers import ValidationError
#       5 from .errors import DataclassTypeError
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\class_validators.py in <module>
#       6 from typing import TYPE_CHECKING, Any, Callable, Dict, Iterable, List, Optional, Set, Tuple, Type, Union, overload
#       7
# ----> 8 from .errors import ConfigError
#       9 from .typing import AnyCallable
#      10 from .utils import ROOT_KEY, in_ipython
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\errors.py in <module>
#       3 from typing import TYPE_CHECKING, Any, Callable, Set, Tuple, Type, Union
#       4
# ----> 5 from .typing import display_as_type
#       6
#       7 if TYPE_CHECKING:
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\typing.py in <module>
#      21 )
#      22
# ---> 23 from typing_extensions import Annotated, Literal
#      24
#      25 try:
#
# ModuleNotFoundError: No module named 'typing_extensions'

# %%
import pandas_profiling
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7544/1591302161.py in <module>
# ----> 1 import pandas_profiling
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\__init__.py in <module>
#       4 """
#       5
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\controller\pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       5
#       6
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\profile_report.py in <module>
#      11 from visions import VisionsTypeset
#      12
# ---> 13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
#      15 from pandas_profiling.model.describe import describe as describe_df
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\config.py in <module>
#       3 from typing import Any, Dict, List, Optional
#       4
# ----> 5 from pydantic import BaseModel, BaseSettings, Field
#       6
#       7
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\__init__.py in <module>
#       1 # flake8: noqa
# ----> 2 from . import dataclasses
#       3 from .annotated_types import create_model_from_namedtuple, create_model_from_typeddict
#       4 from .class_validators import root_validator, validator
#       5 from .decorator import validate_arguments
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\dataclasses.py in <module>
#       1 from typing import TYPE_CHECKING, Any, Callable, Dict, Optional, Type, TypeVar, Union, overload
#       2
# ----> 3 from .class_validators import gather_all_validators
#       4 from .error_wrappers import ValidationError
#       5 from .errors import DataclassTypeError
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\class_validators.py in <module>
#       6 from typing import TYPE_CHECKING, Any, Callable, Dict, Iterable, List, Optional, Set, Tuple, Type, Union, overload
#       7
# ----> 8 from .errors import ConfigError
#       9 from .typing import AnyCallable
#      10 from .utils import ROOT_KEY, in_ipython
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\errors.py in <module>
#       3 from typing import TYPE_CHECKING, Any, Callable, Set, Tuple, Type, Union
#       4
# ----> 5 from .typing import display_as_type
#       6
#       7 if TYPE_CHECKING:
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\typing.py in <module>
#      21 )
#      22
# ---> 23 from typing_extensions import Annotated, Literal
#      24
#      25 try:
#
# ModuleNotFoundError: No module named 'typing_extensions'

# %%
from pandas_profiling.version import __version__
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7544/3688363819.py in <module>
# ----> 1 from pandas_profiling.version import __version__
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\__init__.py in <module>
#       4 """
#       5
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\controller\pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       5
#       6
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\profile_report.py in <module>
#      11 from visions import VisionsTypeset
#      12
# ---> 13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
#      15 from pandas_profiling.model.describe import describe as describe_df
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\config.py in <module>
#       3 from typing import Any, Dict, List, Optional
#       4
# ----> 5 from pydantic import BaseModel, BaseSettings, Field
#       6
#       7
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\__init__.py in <module>
#       1 # flake8: noqa
# ----> 2 from . import dataclasses
#       3 from .annotated_types import create_model_from_namedtuple, create_model_from_typeddict
#       4 from .class_validators import root_validator, validator
#       5 from .decorator import validate_arguments
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\dataclasses.py in <module>
#       1 from typing import TYPE_CHECKING, Any, Callable, Dict, Optional, Type, TypeVar, Union, overload
#       2
# ----> 3 from .class_validators import gather_all_validators
#       4 from .error_wrappers import ValidationError
#       5 from .errors import DataclassTypeError
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\class_validators.py in <module>
#       6 from typing import TYPE_CHECKING, Any, Callable, Dict, Iterable, List, Optional, Set, Tuple, Type, Union, overload
#       7
# ----> 8 from .errors import ConfigError
#       9 from .typing import AnyCallable
#      10 from .utils import ROOT_KEY, in_ipython
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\errors.py in <module>
#       3 from typing import TYPE_CHECKING, Any, Callable, Set, Tuple, Type, Union
#       4
# ----> 5 from .typing import display_as_type
#       6
#       7 if TYPE_CHECKING:
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\typing.py in <module>
#      21 )
#      22
# ---> 23 from typing_extensions import Annotated, Literal
#      24
#      25 try:
#
# ModuleNotFoundError: No module named 'typing_extensions'

# %%
import sys
# !{sys.executable} -m pip install -U pandas-profiling[notebook]
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# 'c:\program' is not recognized as an internal or external command,
# operable program or batch file.
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
import sys

# %%
-m pip install -U pandas-profiling[notebook]
# Out:
#   File "C:\Users\ZAHID\AppData\Local\Temp/ipykernel_7544/626936361.py", line 1
#     -m pip install -U pandas-profiling[notebook]
#        ^
# SyntaxError: invalid syntax

# %%
# !{sys.executable} -m pip install -U pandas-profiling[notebook]
# Out:
# 'c:\program' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import sys
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7544/2934585850.py in <module>
#       1 import sys
# ----> 2 from pandas_profiling import ProfileReport
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\__init__.py in <module>
#       4 """
#       5
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\controller\pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       5
#       6
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\profile_report.py in <module>
#      11 from visions import VisionsTypeset
#      12
# ---> 13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
#      15 from pandas_profiling.model.describe import describe as describe_df
#
# c:\program files\python38\lib\site-packages\pandas_profiling-3.0.0-py3.8.egg\pandas_profiling\config.py in <module>
#       3 from typing import Any, Dict, List, Optional
#       4
# ----> 5 from pydantic import BaseModel, BaseSettings, Field
#       6
#       7
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\__init__.py in <module>
#       1 # flake8: noqa
# ----> 2 from . import dataclasses
#       3 from .annotated_types import create_model_from_namedtuple, create_model_from_typeddict
#       4 from .class_validators import root_validator, validator
#       5 from .decorator import validate_arguments
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\dataclasses.py in <module>
#       1 from typing import TYPE_CHECKING, Any, Callable, Dict, Optional, Type, TypeVar, Union, overload
#       2
# ----> 3 from .class_validators import gather_all_validators
#       4 from .error_wrappers import ValidationError
#       5 from .errors import DataclassTypeError
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\class_validators.py in <module>
#       6 from typing import TYPE_CHECKING, Any, Callable, Dict, Iterable, List, Optional, Set, Tuple, Type, Union, overload
#       7
# ----> 8 from .errors import ConfigError
#       9 from .typing import AnyCallable
#      10 from .utils import ROOT_KEY, in_ipython
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\errors.py in <module>
#       3 from typing import TYPE_CHECKING, Any, Callable, Set, Tuple, Type, Union
#       4
# ----> 5 from .typing import display_as_type
#       6
#       7 if TYPE_CHECKING:
#
# c:\program files\python38\lib\site-packages\pydantic-1.8.2-py3.8.egg\pydantic\typing.py in <module>
#      21 )
#      22
# ---> 23 from typing_extensions import Annotated, Literal
#      24
#      25 try:
#
# ModuleNotFoundError: No module named 'typing_extensions'

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7544/245651692.py in <module>
# ----> 1 from typing_extentions import Annotated, Literal
#
# ModuleNotFoundError: No module named 'typing_extentions'
